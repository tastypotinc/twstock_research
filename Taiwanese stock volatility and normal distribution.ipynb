# %% [markdown]
# # Taiwanese stock volatility and normal distribution

# %%
import datetime as dt
dt.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2016-09-24 21:30:45'

# %%
cd ~/Development/pytwstock/
# Out:
# /home/zhxie/Development/pytwstock

# %%
# %matplotlib inline
from twstock.twstockdb.TWStockDatabase import TWSECDB
twdb = TWSECDB("/d/StockDatabase/twsecdb.scdb")

# %%
tsmc = twdb.query_taiwan_stock_ohlcv_time_series(2330)
hh = twdb.query_taiwan_stock_ohlcv_time_series(2317)
asus = twdb.query_taiwan_stock_ohlcv_time_series(2357)
fubon = twdb.query_taiwan_stock_ohlcv_time_series(2881)
twindex = twdb.query_taiwan_index_time_series()

# %%
tmp = tsmc.shift(1)
tmp = tmp.ix[1:]
tsmc_d2d_volat = (tsmc.close - tmp.close)/tmp.close
tmp = hh.shift(1)
tmp = tmp.ix[1:]
hh_d2d_volat = (hh.close - tmp.close)/tmp.close
tmp = asus.shift(1)
tmp = tmp.ix[1:]
asus_d2d_volat = (asus.close - tmp.close)/tmp.close
tmp = fubon.shift(1)
tmp = tmp.ix[1:]
fubon_d2d_volat = (fubon.close - tmp.close)/tmp.close
tmp = twindex.shift(1)
tmp = tmp.ix[1:]
twindex_d2d_volat = (twindex.close - tmp.close)/tmp.close

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import scipy.stats as stats
import datetime as dt

# %%
n, bins, patches = plt.hist(tsmc_d2d_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = tsmc_d2d_volat.ix[-1500:].std() 
mu = tsmc_d2d_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("TSMC")
plt.show()
stats.normaltest(tsmc_d2d_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=55.505286365205066, pvalue=8.8548295879197981e-13)

# %%
n, bins, patches = plt.hist(hh_d2d_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = hh_d2d_volat.ix[-1500:].std() 
mu = hh_d2d_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Hon Hai")
plt.show()
stats.normaltest(hh_d2d_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=182.55189611738467, pvalue=2.287491176905244e-40)

# %%
n, bins, patches = plt.hist(asus_d2d_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = asus_d2d_volat.ix[-1500:].std() 
mu = asus_d2d_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("ASUS")
plt.show()
stats.normaltest(asus_d2d_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=554.3719892735578, pvalue=4.165355455774929e-121)

# %%
n, bins, patches = plt.hist(fubon_d2d_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = fubon_d2d_volat.ix[-1500:].std() 
mu = fubon_d2d_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Fubon")
plt.show()
stats.normaltest(fubon_d2d_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=91.509562744864468, pvalue=1.345708294494212e-20)

# %%
n, bins, patches = plt.hist(twindex_d2d_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = twindex_d2d_volat.ix[-1500:].std() 
mu = twindex_d2d_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Taiwan Index")
plt.show()
stats.normaltest(twindex_d2d_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=127.91469181488714, pvalue=1.6736999194151187e-28)

# %% [markdown]
# ## Consider volatility in one day

# %%
tsmc_ind_volat = (tsmc.close - tsmc.open)/tsmc.open
hh_ind_volat = (hh.close - hh.open)/hh.open
asus_ind_volat = (asus.close - asus.open)/asus.open
fubon_ind_volat = (fubon.close - fubon.open)/fubon.open
twindex_ind_volat = (twindex.close - twindex.open)/twindex.close

# %%
n, bins, patches = plt.hist(tsmc_ind_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = tsmc_ind_volat.ix[-1500:].std() 
mu = tsmc_ind_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("TSMC")
plt.show()
stats.normaltest(tsmc_ind_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=36.911395961371994, pvalue=9.6558877251765484e-09)

# %%
n, bins, patches = plt.hist(fubon_ind_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = fubon_ind_volat.ix[-1500:].std() 
mu = fubon_ind_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Fubon")
plt.show()
stats.normaltest(fubon_ind_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=80.709991935815978, pvalue=2.9788451921062698e-18)

# %%
n, bins, patches = plt.hist(twindex_ind_volat.ix[-1500:], 50, normed=1, facecolor='blue', alpha=0.75)
sigma = twindex_ind_volat.ix[-1500:].std() 
mu = twindex_ind_volat.ix[-1500:].mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Taiwan Index")
plt.show()
stats.normaltest(twindex_ind_volat.ix[-1500:])
# Out:
# NormaltestResult(statistic=101.37571619648207, pvalue=9.694890950549427e-23)

# %% [markdown]
# ## Check normaltest function

# %%
import numpy as np
mu, sigma = 0, 0.1
s = np.random.normal(mu, sigma, 1500)
n, bins, patches = plt.hist(s, 50, normed=1, facecolor='blue', alpha=0.75)
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Normal")
plt.show()
stats.normaltest(s)
# Out:
# NormaltestResult(statistic=0.31714964276203794, pvalue=0.85335911189496305)

# %% [markdown]
# # Check stock price against lognormal distribution

# %%
price = tsmc.close
logprice = np.log(price)
n, bins, patches = plt.hist(logprice, 50, normed=1, facecolor='blue', alpha=0.75)
sigma = logprice.std() 
mu = logprice.mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("TSMC logprice")
plt.show()
stats.normaltest(logprice)
# Out:
# NormaltestResult(statistic=1305.6337738605043, pvalue=3.0565275378752913e-284)

# %%
price = hh.close
logprice = np.log(price)
n, bins, patches = plt.hist(logprice, 50, normed=1, facecolor='blue', alpha=0.75)
sigma = logprice.std() 
mu = logprice.mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Hon Hai")
plt.show()
stats.normaltest(logprice)
# Out:
# NormaltestResult(statistic=366.25429963701674, pvalue=2.9436715272434492e-80)

# %%
price = fubon.close
logprice = np.log(price)
n, bins, patches = plt.hist(logprice, 50, normed=1, facecolor='blue', alpha=0.75)
sigma = logprice.std() 
mu = logprice.mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Fubon")
plt.show()
stats.normaltest(logprice)
# Out:
# NormaltestResult(statistic=73.566780273711487, pvalue=1.0596846364221676e-16)

# %%
price = twindex.close
logprice = np.log(price)
n, bins, patches = plt.hist(logprice, 50, normed=1, facecolor='blue', alpha=0.75)
sigma = logprice.std() 
mu = logprice.mean() 
y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2)
plt.title("Taiwan index")
plt.show()
stats.normaltest(logprice)
# Out:
# NormaltestResult(statistic=325.96968044399938, pvalue=1.6465815988461879e-71)
